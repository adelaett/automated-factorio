# %%
import json
import fio.blueprint

# %%
fio.blueprint.loads(open("schedule.bp").read())
# Out:
# {'blueprint': {'icons': [{'signal': {'name': 'space-platform-hub'},
#     'index': 1}],
#   'entities': [{'entity_number': 1,
#     'name': 'space-platform-hub',
#     'position': {'x': 0, 'y': 0},
#     'control_behavior': {'read_speed': True,
#      'speed_signal': {'type': 'virtual', 'name': 'signal-V'}},
#     'request_filters': {'sections': [{'index': 1},
#       {'index': 2,
#        'filters': [{'index': 1,
#          'name': 'assembling-machine-3',
#          'quality': 'normal',
#          'comparator': '=',
#          'count': 100},
#         {'index': 2,
#          'name': 'oil-refinery',
#          'quality': 'normal',
#          'comparator': '=',
#          'count': 10},
#         {'index': 3,
#          'name': 'chemical-plant',
#          'quality': 'normal',
#          'comparator': '=',
#          'count': 10},
#         {'index': 4,
#          'name': 'electric-furnace',
#          'quality': 'normal',
#          'comparator': '=',
#          'count': 50},
# ...
